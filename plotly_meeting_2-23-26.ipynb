# %% [markdown]
# Plotly Intro
#
# What is Plotly?
# -Plotly is a free, open source library. It supports several languages including Pythons, JavaScript, R, and MATLAB.
#
# What is Plotly used for?
# -It is used for data visualization, web-based graphics, and interactive dashboards.
#
# Basic plotly charts and interactions (non-technical)
# -Plotly supports several types of charts - basic, financial, statistical and more
# -Charts available: 2D/3D scatter, line, bar, pie, heatmap, candlestick, funnel  and geospatial maps
# -Interactions: hover tooltips, zooming, panning, click-events, and legend toggling for data exploration
#
# Difference between Plotly graph objects (non-technical/just the basics) and Plotly Express
# -Plotly Express is user-friendly and good for quick and simple charts. It is an in-built package that is less customizable.
# -Plotly Graph Objects is for visualizations that are customized or more complex. It is also in-built but is more customizable.

# %%
import plotly.express as pe
import plotly as pl
import plotly.io as pio
import pandas as pd

# %%
df = pd.read_csv("daily_food_delivery_orders.csv")
df
# Out:
#       order_id  order_date  customer_age restaurant_type  order_value  \
# 0            1   11/5/2024            62          Indian       497.51
# 1            2   8/20/2024            35          Bakery       232.32
# 2            3   2/28/2024            34         Italian       540.82
# 3            4   5/26/2024            65            Cafe      1197.99
# 4            5   9/21/2024            40          Indian       947.03
# ...        ...         ...           ...             ...          ...
# 2595      2596   5/20/2024            46            Cafe       738.51
# 2596      2597   5/15/2024            56          Indian       421.78
# 2597      2598  10/18/2024            32            Cafe      1009.93
# 2598      2599   4/24/2024            55          Bakery       240.97
# 2599      2600   1/10/2024            58          Bakery       510.56
#
#       delivery_distance_km  delivery_time_minutes payment_method  \
# 0                    11.07                     79            UPI
# 1                     5.83                     69         Wallet
# 2                     3.61                     70         Wallet
# 3                     3.66                     18           Card
# 4                    12.08                     57            UPI
# ...                    ...                    ...            ...
# 2595                  9.12                     31         Wallet
# 2596                  8.29                     66           Card
# 2597                 12.80                     73            UPI
# 2598                 13.56                     56           Cash
# 2599                  2.30                     49           Cash
#
#       delivery_partner_rating order_status
# 0                         3.9    Cancelled
# 1                         2.7    Cancelled
# 2                         3.4    Cancelled
# 3                         4.6    Cancelled
# 4                         4.9      Delayed
# ...                       ...          ...
# 2595                      4.5    Cancelled
# 2596                      2.8      Delayed
# 2597                      4.4    Delivered
# 2598                      4.3    Delivered
# 2599                      4.2    Delivered
#
# [2600 rows x 10 columns]

# %%
status_counts = df['order_status'].value_counts().reset_index()
status_counts.columns = ['order_status', 'frequency']

# Create bar chart
fig = pe.bar(
    status_counts,
    x='order_status',
    y='frequency',
    title='Frequency of Order Status',
    labels={'order_status': 'Order Status', 'frequency': 'Frequency'}
   
)

fig.show()

# %%
fig = pe.bar(
    status_counts,
    x='order_status',
    y='frequency',
    color='order_status',
    color_discrete_map={
        'Delivered': 'green',
        'Cancelled': 'red',
        'Delayed': 'yellow'
    },
    labels={'order_status': 'Order Status', 'frequency': 'Frequency'},
    title='Frequency of Order Status',

)

#With legend to the right
fig.show()

# %%
fig = pe.bar(
    status_counts,
    x='order_status',
    y='frequency',
    color='order_status',
    color_discrete_map={
        'Delivered': 'green',
        'Cancelled': 'red',
        'Delayed': 'yellow'
    },
    labels={'order_status': 'Order Status', 'frequency': 'Frequency'},
    title='Frequency of Order Status',

)

# Rename legend title
fig.update_layout(legend_title_text='Legend')

#With legend to the right
fig.show()

# %%
fig = pe.bar(
    status_counts,
    x='order_status',
    y='frequency',
    color='order_status',
    color_discrete_map={
        'Delivered': 'green',
        'Cancelled': 'red',
        'Delayed': 'yellow'
    },
    labels={'order_status': 'Order Status', 'frequency': 'Frequency'},
    title='Frequency of Order Status',

)
#Remove the Legend
fig.update_layout(showlegend=False)

fig.show()

# %%
fig = pe.bar(
    status_counts,
    x='order_status',
    y='frequency',
    color='order_status',
    color_discrete_map={
        'Delivered': 'green',
        'Cancelled': 'red',
        'Delayed': 'yellow'
    },
    labels={'order_status': 'Order Status', 'frequency': 'Frequency'},
    title='Frequency of Order Status',
)

#Remove the Legend
fig.update_layout(showlegend=False)

fig.show()

# %%
fig = pe.bar(
    status_counts,
    x='order_status',
    y='frequency',
    color='order_status',
    color_discrete_map={
        'Delivered': 'green',
        'Cancelled': 'red',
        'Delayed': 'yellow'
    },
    labels={'order_status': 'Order Status', 'frequency': 'Frequency'},
    title='Frequency of Order Status',
)

#Add Frequency count above each bar in black
fig.update_traces(
    textposition="outside",
    textfont=dict(color="black")
)

#Remove the Legend
fig.update_layout(showlegend=False)

fig.show()
