# %% [markdown]
# # Systems Check
# ### Darlene Janke
# #### EMAT 62110
#
# Making a list
# - thing one
# 1. Thing one
#
# _italics_ __bold__

# %%
my_name = "Darlene"
my_name
# Out:
# 'Darlene'

# %%
def give_name():
    print(my_name)
give_name()
# Out:
# Darlene

# %%
def return_name():
    return my_name
new_name = return_name()

# %% [markdown]
# # __Assignment__
# ## _Systems Check_
# #### January 20, 2026
#
# ![Image](https://thumbs.dreamstime.com/b/big-smile-emoticon-26256350.jpg)
#
#
# My goals for this class include learning:
# - Python Coding
# - Data Visualization Integration
